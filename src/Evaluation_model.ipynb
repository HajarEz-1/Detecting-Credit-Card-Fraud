# %%
from sklearn.metrics import classification_report, confusion_matrix
import joblib
import os
import seaborn as sns
import matplotlib.pyplot as plt

# Load the test data (ensure this is done before starting the evaluation)
X_test_orig = joblib.load('../Data/X_test_orig.joblib')  # Replace with actual test data loading
y_test_orig = joblib.load('../Data/y_test_orig.joblib')  # Replace with actual test data loading

# %%
# Initialize the models dictionary again (you may need this to reference the models)
models = {
    "RandomForest": joblib.load('../Models/RandomForest_model.joblib'),
    "SVM": joblib.load('../Models/SVM_model.joblib'),
}

# Evaluate each model
for model_name, model in models.items():
    # Predict with the model on the test data
    y_pred = model.predict(X_test_orig)
    
    # Generate classification report
    report = classification_report(y_test_orig, y_pred)
    print(f"Classification Report for {model_name}:\n", report)
    
    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_test_orig, y_pred)
    
    # Plot the confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Non-Fraud', 'Fraud'], 
                yticklabels=['Non-Fraud', 'Fraud'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.show()
# Out:
# Classification Report for RandomForest:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     56864
#            1       0.04      0.92      0.08        98
#
#     accuracy                           0.96     56962
#    macro avg       0.52      0.94      0.53     56962
# weighted avg       1.00      0.96      0.98     56962
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.08      0.91      0.15        98
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.95      0.57     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
# Initialize the models dictionary again (you may need this to reference the models)
models = {
    "KNN": joblib.load('../Models/KNN_model.joblib'),
    "LogisticRegression": joblib.load('../Models/LogisticRegression_model.joblib'),
}

# Evaluate each model
for model_name, model in models.items():
    # Predict with the model on the test data
    y_pred = model.predict(X_test_orig)
    
    # Generate classification report
    report = classification_report(y_test_orig, y_pred)
    print(f"Classification Report for {model_name}:\n", report)
    
    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_test_orig, y_pred)
    
    # Plot the confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Non-Fraud', 'Fraud'], 
                yticklabels=['Non-Fraud', 'Fraud'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.show()
# Out:
# Classification Report for KNN:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.90      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.93      0.54     56962
# weighted avg       1.00      0.97      0.98     56962
# Classification Report for LogisticRegression:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     56864
#            1       0.04      0.93      0.08        98
#
#     accuracy                           0.96     56962
#    macro avg       0.52      0.95      0.53     56962
# weighted avg       1.00      0.96      0.98     56962

# %%
model =  joblib.load('../Models/GradientBoosting_model.joblib')

y_pred = model.predict(X_test_orig)
    
    
report = classification_report(y_test_orig, y_pred)
print(f"Classification Report for GradientBoosting_model:\n", report)
    
# Generate confusion matrix
conf_matrix = confusion_matrix(y_test_orig, y_pred)
    
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Fraud', 'Fraud'], 
            yticklabels=['Non-Fraud', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f'Confusion Matrix - GradientBoosting_model')
plt.show()
# Out:
# Classification Report for GradientBoosting_model:
#                precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     56864
#            1       0.03      0.93      0.06        98
#
#     accuracy                           0.95     56962
#    macro avg       0.52      0.94      0.52     56962
# weighted avg       1.00      0.95      0.97     56962
